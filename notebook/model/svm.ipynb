# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
import os

# %%
df = pd.read_csv("../../data/data_processed/data_processed.csv")
df.columns[0]
# Out:
# 'LB'

# %%
def evaluate_model(X_train, X_test, y_train, y_test, kernel):
    # model = SVC(kernel=kernel, random_state=42)
    model = SVC(kernel=kernel,  class_weight="balanced", decision_function_shape='ovr', C=100, gamma=0.1, random_state=42)
    model.fit(X_train, y_train)

    print("[Train] Classification Report:")
    print(classification_report(y_train, model.predict(X_train)))

    print("[Test] Classification Report:")
    print(classification_report(y_test, model.predict(X_test)))

# Xử lý dữ liệu gốc theo tỉ lệ và áp dụng SVM
def process_original_data(df, ratio, kernel):
    X = df.drop('NSP', axis=1)
    y = df['NSP']

    scaler = StandardScaler()

    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=1 - ratio, stratify=y, random_state=42
    )

    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    print(f"\nMô hình SVM với dữ liệu gốc - Tỉ lệ = {int(ratio*10)}:{int((1-ratio)*10)} --- Kernel = {kernel} ---")
    evaluate_model(X_train, X_test, y_train, y_test, kernel=kernel)

# %%
def process_presplit_data(train_path, test_path, kernel, target_col, method):
    # Đọc dữ liệu
    train_data = pd.read_csv(train_path).iloc[:, 1:]
    test_data = pd.read_csv(test_path).iloc[:, 1:]

    # Tách X và y
    X_train = train_data.drop('NSP', axis=1).values
    y_train = train_data['NSP'].values

    X_test = test_data.drop('NSP', axis=1).values
    y_test = test_data['NSP'].values

    print(f"\nMô hình SVM với dữ liệu giảm chiều bằng {method} tỉ lệ {split} --- Kernel = {kernel} ---")


    # Huấn luyện và đánh giá
    model = SVC(kernel=kernel,  class_weight="balanced", decision_function_shape='ovr', C=100, gamma=0.1, random_state=42)
    model.fit(X_train, y_train)

    print("[Train] Classification Report:")
    print(classification_report(y_train, model.predict(X_train)))

    print("[Test] Classification Report:")
    print(classification_report(y_test, model.predict(X_test)))

# %% [markdown]
# Dữ liệu gốc

# %%
kernels = ['linear','sigmoid', 'poly', 'rbf']
for kernel in kernels:
    for r in [0.8, 0.7, 0.6]:
        process_original_data(df, r, kernel)
# Out:
# Mô hình SVM với dữ liệu gốc - Tỉ lệ = 8:1 --- Kernel = linear ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.89      0.94      1323
#          2.0       0.59      0.88      0.71       236
#          3.0       0.79      0.92      0.85       141
#
#     accuracy                           0.89      1700
#    macro avg       0.79      0.90      0.83      1700
# weighted avg       0.92      0.89      0.90      1700
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.89      0.93       332
#          2.0       0.56      0.85      0.68        59
#          3.0       0.72      0.80      0.76        35
#
#     accuracy                           0.87       426
#    macro avg       0.76      0.84      0.79       426
# weighted avg       0.91      0.87      0.88       426
#
#
# Mô hình SVM với dữ liệu gốc - Tỉ lệ = 7:3 --- Kernel = linear ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.89      0.94      1158
#          2.0       0.59      0.86      0.70       207
#          3.0       0.78      0.92      0.85       123
#
#     accuracy                           0.89      1488
#    macro avg       0.79      0.89      0.83      1488
# weighted avg       0.92      0.89      0.90      1488
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.98      0.88      0.93       497
#          2.0       0.53      0.88      0.66        88
#          3.0       0.84      0.77      0.80        53
#
#     accuracy                           0.87       638
#    macro avg       0.78      0.84      0.80       638
# weighted avg       0.91      0.87      0.88       638
#
#
# Mô hình SVM với dữ liệu gốc - Tỉ lệ = 6:4 --- Kernel = linear ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.89      0.94       992
#          2.0       0.60      0.86      0.71       177
#          3.0       0.77      0.93      0.84       106
#
#     accuracy                           0.89      1275
#    macro avg       0.79      0.90      0.83      1275
# weighted avg       0.92      0.89      0.90      1275
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.98      0.89      0.93       663
#          2.0       0.55      0.83      0.66       118
#          3.0       0.79      0.81      0.80        70
#
#     accuracy                           0.87       851
#    macro avg       0.77      0.84      0.80       851
# weighted avg       0.90      0.87      0.88       851
#
#
# Mô hình SVM với dữ liệu gốc - Tỉ lệ = 8:1 --- Kernel = sigmoid ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.88      0.78      0.83      1323
#          2.0       0.40      0.51      0.45       236
#          3.0       0.24      0.38      0.29       141
#
#     accuracy                           0.71      1700
#    macro avg       0.51      0.56      0.52      1700
# weighted avg       0.76      0.71      0.73      1700
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.86      0.76      0.80       332
#          2.0       0.35      0.53      0.42        59
#          3.0       0.16      0.20      0.18        35
#
#     accuracy                           0.68       426
#    macro avg       0.45      0.49      0.47       426
# weighted avg       0.73      0.68      0.70       426
#
#
# Mô hình SVM với dữ liệu gốc - Tỉ lệ = 7:3 --- Kernel = sigmoid ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.88      0.70      0.78      1158
#          2.0       0.32      0.49      0.39       207
#          3.0       0.20      0.40      0.26       123
#
#     accuracy                           0.65      1488
#    macro avg       0.47      0.53      0.48      1488
# weighted avg       0.74      0.65      0.68      1488
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.85      0.71      0.77       497
#          2.0       0.30      0.49      0.38        88
#          3.0       0.22      0.36      0.27        53
#
#     accuracy                           0.65       638
#    macro avg       0.46      0.52      0.47       638
# weighted avg       0.73      0.65      0.68       638
#
#
# Mô hình SVM với dữ liệu gốc - Tỉ lệ = 6:4 --- Kernel = sigmoid ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.88      0.53      0.66       992
#          2.0       0.38      0.59      0.46       177
#          3.0       0.14      0.52      0.22       106
#
#     accuracy                           0.54      1275
#    macro avg       0.47      0.55      0.45      1275
# weighted avg       0.75      0.54      0.60      1275
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.88      0.54      0.67       663
#          2.0       0.38      0.61      0.47       118
#          3.0       0.12      0.43      0.18        70
#
#     accuracy                           0.54       851
#    macro avg       0.46      0.53      0.44       851
# weighted avg       0.75      0.54      0.60       851
#
#
# Mô hình SVM với dữ liệu gốc - Tỉ lệ = 8:1 --- Kernel = poly ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       1.00      0.99      1.00      1323
#          2.0       0.95      1.00      0.97       236
#          3.0       0.99      1.00      1.00       141
#
#     accuracy                           0.99      1700
#    macro avg       0.98      1.00      0.99      1700
# weighted avg       0.99      0.99      0.99      1700
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.95      0.95      0.95       332
#          2.0       0.67      0.69      0.68        59
#          3.0       0.79      0.74      0.76        35
#
#     accuracy                           0.89       426
#    macro avg       0.80      0.79      0.80       426
# weighted avg       0.89      0.89      0.89       426
#
#
# Mô hình SVM với dữ liệu gốc - Tỉ lệ = 7:3 --- Kernel = poly ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       1.00      0.99      1.00      1158
#          2.0       0.96      1.00      0.98       207
#          3.0       0.99      1.00      1.00       123
#
#     accuracy                           0.99      1488
#    macro avg       0.98      1.00      0.99      1488
# weighted avg       0.99      0.99      0.99      1488
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.94      0.94      0.94       497
#          2.0       0.61      0.67      0.64        88
#          3.0       0.84      0.70      0.76        53
#
#     accuracy                           0.89       638
#    macro avg       0.80      0.77      0.78       638
# weighted avg       0.89      0.89      0.89       638
#
#
# Mô hình SVM với dữ liệu gốc - Tỉ lệ = 6:4 --- Kernel = poly ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       1.00      0.99      1.00       992
#          2.0       0.96      0.99      0.98       177
#          3.0       0.99      1.00      1.00       106
#
#     accuracy                           0.99      1275
#    macro avg       0.98      1.00      0.99      1275
# weighted avg       0.99      0.99      0.99      1275
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.94      0.94      0.94       663
#          2.0       0.63      0.67      0.65       118
#          3.0       0.81      0.71      0.76        70
#
#     accuracy                           0.88       851
#    macro avg       0.79      0.77      0.78       851
# weighted avg       0.88      0.88      0.88       851
#
#
# Mô hình SVM với dữ liệu gốc - Tỉ lệ = 8:1 --- Kernel = rbf ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       1.00      0.99      1.00      1323
#          2.0       0.95      1.00      0.97       236
#          3.0       0.99      0.99      0.99       141
#
#     accuracy                           0.99      1700
#    macro avg       0.98      0.99      0.99      1700
# weighted avg       0.99      0.99      0.99      1700
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.95      0.97      0.96       332
#          2.0       0.74      0.68      0.71        59
#          3.0       0.85      0.83      0.84        35
#
#     accuracy                           0.92       426
#    macro avg       0.85      0.82      0.84       426
# weighted avg       0.91      0.92      0.91       426
#
#
# Mô hình SVM với dữ liệu gốc - Tỉ lệ = 7:3 --- Kernel = rbf ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       1.00      0.99      0.99      1158
#          2.0       0.94      1.00      0.97       207
#          3.0       0.99      0.99      0.99       123
#
#     accuracy                           0.99      1488
#    macro avg       0.98      0.99      0.98      1488
# weighted avg       0.99      0.99      0.99      1488
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.94      0.97      0.95       497
#          2.0       0.74      0.66      0.70        88
#          3.0       0.85      0.75      0.80        53
#
#     accuracy                           0.91       638
#    macro avg       0.84      0.79      0.82       638
# weighted avg       0.91      0.91      0.91       638
#
#
# Mô hình SVM với dữ liệu gốc - Tỉ lệ = 6:4 --- Kernel = rbf ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       1.00      0.99      1.00       992
#          2.0       0.96      0.99      0.98       177
#          3.0       0.99      1.00      1.00       106
#
#     accuracy                           0.99      1275
#    macro avg       0.98      1.00      0.99      1275
# weighted avg       0.99      0.99      0.99      1275
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.94      0.97      0.95       663
#          2.0       0.73      0.68      0.70       118
#          3.0       0.86      0.73      0.79        70
#
#     accuracy                           0.91       851
#    macro avg       0.85      0.79      0.82       851
# weighted avg       0.90      0.91      0.90       851

# %% [markdown]
# Dữ liệu giảm chiều bằng PCA

# %%
file_paths_pca = {
    "80_20": {
        'train': r'..\..\data\dimension_reduction\pca\train_80.csv',
        'test': r'..\..\data\dimension_reduction\pca\test_20.csv'
    },
    "70_30": {
        'train': r'..\..\data\dimension_reduction\pca\train_70.csv',
        'test': r'..\..\data\dimension_reduction\pca\test_30.csv'
    },
    "60_40": {
        'train': r'..\..\data\dimension_reduction\pca\train_60.csv',
        'test': r'..\..\data\dimension_reduction\pca\test_40.csv'
    }
}
for kernel in kernels:
    for split, paths in file_paths_pca.items():
        process_presplit_data(
            train_path=paths['train'],
            test_path=paths['test'],
            kernel = kernel,
            target_col='Target',
            method=f'PCA'
        )
# Out:
# Mô hình SVM với dữ liệu giảm chiều bằng PCA tỉ lệ 80_20 --- Kernel = linear ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.87      0.93      1323
#          2.0       0.55      0.86      0.67       236
#          3.0       0.76      0.90      0.82       141
#
#     accuracy                           0.87      1700
#    macro avg       0.77      0.88      0.81      1700
# weighted avg       0.91      0.87      0.88      1700
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.98      0.86      0.91       332
#          2.0       0.51      0.85      0.63        59
#          3.0       0.76      0.83      0.79        35
#
#     accuracy                           0.85       426
#    macro avg       0.75      0.84      0.78       426
# weighted avg       0.90      0.85      0.87       426
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng PCA tỉ lệ 70_30 --- Kernel = linear ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.87      0.93      1158
#          2.0       0.55      0.89      0.68       207
#          3.0       0.81      0.85      0.83       123
#
#     accuracy                           0.88      1488
#    macro avg       0.78      0.87      0.81      1488
# weighted avg       0.91      0.88      0.89      1488
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.98      0.86      0.92       497
#          2.0       0.50      0.89      0.64        88
#          3.0       0.83      0.75      0.79        53
#
#     accuracy                           0.85       638
#    macro avg       0.77      0.83      0.78       638
# weighted avg       0.90      0.85      0.87       638
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng PCA tỉ lệ 60_40 --- Kernel = linear ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.87      0.93       992
#          2.0       0.55      0.88      0.67       177
#          3.0       0.80      0.87      0.83       106
#
#     accuracy                           0.87      1275
#    macro avg       0.78      0.87      0.81      1275
# weighted avg       0.91      0.87      0.88      1275
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.87      0.92       663
#          2.0       0.52      0.89      0.66       118
#          3.0       0.79      0.77      0.78        70
#
#     accuracy                           0.86       851
#    macro avg       0.77      0.84      0.79       851
# weighted avg       0.91      0.86      0.87       851
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng PCA tỉ lệ 80_20 --- Kernel = sigmoid ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.88      0.76      0.82      1323
#          2.0       0.38      0.49      0.43       236
#          3.0       0.21      0.38      0.27       141
#
#     accuracy                           0.69      1700
#    macro avg       0.49      0.54      0.51      1700
# weighted avg       0.76      0.69      0.72      1700
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.85      0.73      0.79       332
#          2.0       0.34      0.53      0.41        59
#          3.0       0.12      0.17      0.14        35
#
#     accuracy                           0.66       426
#    macro avg       0.44      0.48      0.45       426
# weighted avg       0.72      0.66      0.68       426
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng PCA tỉ lệ 70_30 --- Kernel = sigmoid ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.88      0.53      0.67      1158
#          2.0       0.39      0.57      0.46       207
#          3.0       0.13      0.51      0.21       123
#
#     accuracy                           0.54      1488
#    macro avg       0.47      0.54      0.45      1488
# weighted avg       0.75      0.54      0.60      1488
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.85      0.51      0.64       497
#          2.0       0.34      0.59      0.44        88
#          3.0       0.10      0.34      0.15        53
#
#     accuracy                           0.51       638
#    macro avg       0.43      0.48      0.41       638
# weighted avg       0.72      0.51      0.57       638
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng PCA tỉ lệ 60_40 --- Kernel = sigmoid ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.93      0.53      0.67       992
#          2.0       0.41      0.63      0.50       177
#          3.0       0.14      0.58      0.23       106
#
#     accuracy                           0.55      1275
#    macro avg       0.49      0.58      0.46      1275
# weighted avg       0.79      0.55      0.61      1275
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.91      0.52      0.66       663
#          2.0       0.41      0.64      0.50       118
#          3.0       0.09      0.39      0.15        70
#
#     accuracy                           0.53       851
#    macro avg       0.47      0.52      0.44       851
# weighted avg       0.77      0.53      0.60       851
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng PCA tỉ lệ 80_20 --- Kernel = poly ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       1.00      0.97      0.98      1323
#          2.0       0.85      1.00      0.91       236
#          3.0       1.00      0.99      1.00       141
#
#     accuracy                           0.97      1700
#    macro avg       0.95      0.99      0.96      1700
# weighted avg       0.98      0.97      0.97      1700
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.95      0.94      0.95       332
#          2.0       0.63      0.69      0.66        59
#          3.0       0.88      0.83      0.85        35
#
#     accuracy                           0.90       426
#    macro avg       0.82      0.82      0.82       426
# weighted avg       0.90      0.90      0.90       426
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng PCA tỉ lệ 70_30 --- Kernel = poly ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       1.00      0.96      0.98      1158
#          2.0       0.81      1.00      0.89       207
#          3.0       1.00      0.99      1.00       123
#
#     accuracy                           0.97      1488
#    macro avg       0.94      0.98      0.96      1488
# weighted avg       0.97      0.97      0.97      1488
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.94      0.93      0.93       497
#          2.0       0.59      0.65      0.62        88
#          3.0       0.89      0.77      0.83        53
#
#     accuracy                           0.88       638
#    macro avg       0.80      0.78      0.79       638
# weighted avg       0.88      0.88      0.88       638
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng PCA tỉ lệ 60_40 --- Kernel = poly ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       1.00      0.97      0.98       992
#          2.0       0.84      0.99      0.91       177
#          3.0       1.00      0.99      1.00       106
#
#     accuracy                           0.97      1275
#    macro avg       0.95      0.98      0.96      1275
# weighted avg       0.98      0.97      0.97      1275
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.93      0.93      0.93       663
#          2.0       0.62      0.68      0.65       118
#          3.0       0.84      0.73      0.78        70
#
#     accuracy                           0.88       851
#    macro avg       0.80      0.78      0.79       851
# weighted avg       0.88      0.88      0.88       851
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng PCA tỉ lệ 80_20 --- Kernel = rbf ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       1.00      0.98      0.99      1323
#          2.0       0.91      0.99      0.95       236
#          3.0       0.99      0.99      0.99       141
#
#     accuracy                           0.98      1700
#    macro avg       0.96      0.99      0.98      1700
# weighted avg       0.99      0.98      0.98      1700
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.95      0.95      0.95       332
#          2.0       0.69      0.68      0.68        59
#          3.0       0.76      0.80      0.78        35
#
#     accuracy                           0.90       426
#    macro avg       0.80      0.81      0.80       426
# weighted avg       0.90      0.90      0.90       426
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng PCA tỉ lệ 70_30 --- Kernel = rbf ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       1.00      0.98      0.99      1158
#          2.0       0.90      0.99      0.94       207
#          3.0       0.98      0.99      0.99       123
#
#     accuracy                           0.98      1488
#    macro avg       0.96      0.99      0.97      1488
# weighted avg       0.98      0.98      0.98      1488
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.94      0.95      0.94       497
#          2.0       0.66      0.64      0.65        88
#          3.0       0.80      0.77      0.79        53
#
#     accuracy                           0.89       638
#    macro avg       0.80      0.79      0.79       638
# weighted avg       0.89      0.89      0.89       638
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng PCA tỉ lệ 60_40 --- Kernel = rbf ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       1.00      0.98      0.99       992
#          2.0       0.91      0.99      0.95       177
#          3.0       0.98      1.00      0.99       106
#
#     accuracy                           0.99      1275
#    macro avg       0.96      0.99      0.98      1275
# weighted avg       0.99      0.99      0.99      1275
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.94      0.95      0.95       663
#          2.0       0.69      0.67      0.68       118
#          3.0       0.86      0.80      0.83        70
#
#     accuracy                           0.90       851
#    macro avg       0.83      0.81      0.82       851
# weighted avg       0.90      0.90      0.90       851

# %% [markdown]
# Dữ liệu giảm chiều bằng LDA

# %%
file_paths_lda = {
    "80_20": {
        'train': r'..\..\data\dimension_reduction\lda\train_80.csv',
        'test': r'..\..\data\dimension_reduction\lda\test_20.csv'
    },
    "70_30": {
        'train': r'..\..\data\dimension_reduction\lda\train_70.csv',
        'test': r'..\..\data\dimension_reduction\lda\test_30.csv'
    },
    "60_40": {
        'train': r'..\..\data\dimension_reduction\lda\train_60.csv',
        'test': r'..\..\data\dimension_reduction\lda\test_40.csv'
    }
}
for kernel in kernels:
    for split, paths in file_paths_lda.items():
        process_presplit_data(
            train_path=paths['train'],
            test_path=paths['test'],
            kernel = kernel,
            target_col='Target',
            method=f'LDA'
        )
# Out:
# Mô hình SVM với dữ liệu giảm chiều bằng LDA tỉ lệ 80_20 --- Kernel = linear ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.98      0.84      0.91      1323
#          2.0       0.51      0.85      0.64       236
#          3.0       0.68      0.84      0.75       141
#
#     accuracy                           0.84      1700
#    macro avg       0.72      0.84      0.76      1700
# weighted avg       0.89      0.84      0.86      1700
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.98      0.85      0.91       332
#          2.0       0.51      0.83      0.63        59
#          3.0       0.66      0.77      0.71        35
#
#     accuracy                           0.84       426
#    macro avg       0.72      0.82      0.75       426
# weighted avg       0.89      0.84      0.86       426
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng LDA tỉ lệ 70_30 --- Kernel = linear ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.98      0.85      0.91      1158
#          2.0       0.53      0.86      0.65       207
#          3.0       0.69      0.85      0.76       123
#
#     accuracy                           0.85      1488
#    macro avg       0.73      0.85      0.78      1488
# weighted avg       0.90      0.85      0.86      1488
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.97      0.86      0.91       497
#          2.0       0.49      0.84      0.62        88
#          3.0       0.78      0.74      0.76        53
#
#     accuracy                           0.84       638
#    macro avg       0.75      0.81      0.76       638
# weighted avg       0.89      0.84      0.86       638
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng LDA tỉ lệ 60_40 --- Kernel = linear ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.84      0.91       992
#          2.0       0.52      0.85      0.65       177
#          3.0       0.65      0.86      0.74       106
#
#     accuracy                           0.84      1275
#    macro avg       0.72      0.85      0.77      1275
# weighted avg       0.89      0.84      0.86      1275
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.84      0.91       663
#          2.0       0.50      0.86      0.63       118
#          3.0       0.72      0.81      0.77        70
#
#     accuracy                           0.84       851
#    macro avg       0.73      0.84      0.77       851
# weighted avg       0.90      0.84      0.86       851
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng LDA tỉ lệ 80_20 --- Kernel = sigmoid ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.97      0.81      0.88      1323
#          2.0       0.47      0.68      0.56       236
#          3.0       0.41      0.76      0.53       141
#
#     accuracy                           0.79      1700
#    macro avg       0.62      0.75      0.66      1700
# weighted avg       0.86      0.79      0.81      1700
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.98      0.81      0.88       332
#          2.0       0.48      0.73      0.58        59
#          3.0       0.38      0.69      0.49        35
#
#     accuracy                           0.79       426
#    macro avg       0.61      0.74      0.65       426
# weighted avg       0.86      0.79      0.81       426
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng LDA tỉ lệ 70_30 --- Kernel = sigmoid ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.97      0.81      0.88      1158
#          2.0       0.49      0.68      0.57       207
#          3.0       0.40      0.76      0.52       123
#
#     accuracy                           0.79      1488
#    macro avg       0.62      0.75      0.66      1488
# weighted avg       0.86      0.79      0.81      1488
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.96      0.80      0.87       497
#          2.0       0.46      0.75      0.57        88
#          3.0       0.39      0.62      0.48        53
#
#     accuracy                           0.78       638
#    macro avg       0.61      0.72      0.64       638
# weighted avg       0.85      0.78      0.80       638
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng LDA tỉ lệ 60_40 --- Kernel = sigmoid ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.97      0.81      0.88       992
#          2.0       0.48      0.67      0.56       177
#          3.0       0.39      0.75      0.51       106
#
#     accuracy                           0.78      1275
#    macro avg       0.61      0.74      0.65      1275
# weighted avg       0.86      0.78      0.81      1275
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.98      0.81      0.88       663
#          2.0       0.46      0.69      0.56       118
#          3.0       0.39      0.70      0.50        70
#
#     accuracy                           0.78       851
#    macro avg       0.61      0.73      0.65       851
# weighted avg       0.86      0.78      0.81       851
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng LDA tỉ lệ 80_20 --- Kernel = poly ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.96      0.91      0.94      1323
#          2.0       0.59      0.81      0.68       236
#          3.0       0.87      0.78      0.82       141
#
#     accuracy                           0.89      1700
#    macro avg       0.81      0.83      0.81      1700
# weighted avg       0.90      0.89      0.89      1700
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.97      0.92      0.94       332
#          2.0       0.57      0.76      0.65        59
#          3.0       0.75      0.69      0.72        35
#
#     accuracy                           0.88       426
#    macro avg       0.76      0.79      0.77       426
# weighted avg       0.89      0.88      0.88       426
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng LDA tỉ lệ 70_30 --- Kernel = poly ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.97      0.92      0.94      1158
#          2.0       0.60      0.80      0.69       207
#          3.0       0.83      0.80      0.81       123
#
#     accuracy                           0.89      1488
#    macro avg       0.80      0.84      0.81      1488
# weighted avg       0.90      0.89      0.89      1488
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.97      0.91      0.94       497
#          2.0       0.57      0.81      0.67        88
#          3.0       0.80      0.68      0.73        53
#
#     accuracy                           0.88       638
#    macro avg       0.78      0.80      0.78       638
# weighted avg       0.90      0.88      0.88       638
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng LDA tỉ lệ 60_40 --- Kernel = poly ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.97      0.91      0.94       992
#          2.0       0.60      0.79      0.68       177
#          3.0       0.78      0.81      0.80       106
#
#     accuracy                           0.88      1275
#    macro avg       0.78      0.83      0.80      1275
# weighted avg       0.90      0.88      0.89      1275
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.97      0.90      0.94       663
#          2.0       0.59      0.84      0.69       118
#          3.0       0.77      0.73      0.75        70
#
#     accuracy                           0.88       851
#    macro avg       0.78      0.82      0.79       851
# weighted avg       0.90      0.88      0.89       851
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng LDA tỉ lệ 80_20 --- Kernel = rbf ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.82      0.90      1323
#          2.0       0.50      0.92      0.64       236
#          3.0       0.70      0.84      0.77       141
#
#     accuracy                           0.84      1700
#    macro avg       0.73      0.86      0.77      1700
# weighted avg       0.90      0.84      0.85      1700
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.84      0.91       332
#          2.0       0.49      0.85      0.62        59
#          3.0       0.65      0.80      0.72        35
#
#     accuracy                           0.84       426
#    macro avg       0.71      0.83      0.75       426
# weighted avg       0.89      0.84      0.85       426
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng LDA tỉ lệ 70_30 --- Kernel = rbf ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.83      0.91      1158
#          2.0       0.52      0.92      0.67       207
#          3.0       0.68      0.86      0.76       123
#
#     accuracy                           0.85      1488
#    macro avg       0.73      0.87      0.78      1488
# weighted avg       0.90      0.85      0.86      1488
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.83      0.90       497
#          2.0       0.48      0.86      0.62        88
#          3.0       0.65      0.77      0.71        53
#
#     accuracy                           0.83       638
#    macro avg       0.71      0.82      0.74       638
# weighted avg       0.89      0.83      0.85       638
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng LDA tỉ lệ 60_40 --- Kernel = rbf ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.83      0.90       992
#          2.0       0.52      0.92      0.66       177
#          3.0       0.67      0.84      0.74       106
#
#     accuracy                           0.84      1275
#    macro avg       0.73      0.86      0.77      1275
# weighted avg       0.90      0.84      0.86      1275
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.84      0.91       663
#          2.0       0.51      0.92      0.65       118
#          3.0       0.68      0.77      0.72        70
#
#     accuracy                           0.84       851
#    macro avg       0.73      0.84      0.76       851
# weighted avg       0.90      0.84      0.86       851
