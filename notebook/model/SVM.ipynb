# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
import os

# %%
df = pd.read_csv("../../data/data_processed/data_processed.csv")
df.columns[0]
# Out:
# 'LB'

# %%
def evaluate_model(X_train, X_test, y_train, y_test, kernel):
    # model = SVC(kernel=kernel, random_state=42)
    model = SVC(kernel=kernel, class_weight='balanced', decision_function_shape='ovr', random_state=42)
    model.fit(X_train, y_train)

    print("[Train] Classification Report:")
    print(classification_report(y_train, model.predict(X_train)))

    print("[Test] Classification Report:")
    print(classification_report(y_test, model.predict(X_test)))

# Xử lý dữ liệu gốc theo tỉ lệ và áp dụng SVM
def process_original_data(df, ratio, kernel):
    X = df.drop('NSP', axis=1)
    y = df['NSP']

    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    X_train, X_test, y_train, y_test = train_test_split(
        X_scaled, y, test_size=1 - ratio, stratify=y, random_state=42
    )

    print(f"\nMô hình SVM với dữ liệu gốc - Tỉ lệ = {int(ratio*10)}:{int((1-ratio)*10)} --- Kernel = {kernel} ---")
    evaluate_model(X_train, X_test, y_train, y_test, kernel=kernel)

# %%
def process_presplit_data(train_path, test_path, kernel, target_col, method):
    # Đọc dữ liệu
    train_data = pd.read_csv(train_path).iloc[:, 1:]
    test_data = pd.read_csv(test_path).iloc[:, 1:]

    # Tách X và y
    X_train = train_data.drop('NSP', axis=1).values
    y_train = train_data['NSP'].values

    X_test = test_data.drop('NSP', axis=1).values
    y_test = test_data['NSP'].values

    print(f"\nMô hình SVM với dữ liệu giảm chiều bằng {method} tỉ lệ {split} --- Kernel = {kernel} ---")


    # Huấn luyện và đánh giá
    model = SVC(kernel=kernel, class_weight='balanced', decision_function_shape='ovr', random_state=42)
    model.fit(X_train, y_train)

    print("[Train] Classification Report:")
    print(classification_report(y_train, model.predict(X_train)))

    print("[Test] Classification Report:")
    print(classification_report(y_test, model.predict(X_test)))

# %% [markdown]
# Dữ liệu gốc

# %%
kernels = ['linear','sigmoid', 'poly', 'rbf']
for kernel in kernels:
    for r in [0.8, 0.7, 0.6]:
        process_original_data(df, r, kernel)
# Out:
# Mô hình SVM với dữ liệu gốc - Tỉ lệ = 8:1 --- Kernel = linear ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.89      0.94      1323
#          2.0       0.59      0.89      0.71       236
#          3.0       0.78      0.91      0.84       141
#
#     accuracy                           0.89      1700
#    macro avg       0.79      0.90      0.83      1700
# weighted avg       0.92      0.89      0.90      1700
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.89      0.94       332
#          2.0       0.57      0.90      0.70        59
#          3.0       0.83      0.83      0.83        35
#
#     accuracy                           0.88       426
#    macro avg       0.80      0.87      0.82       426
# weighted avg       0.92      0.88      0.89       426
#
#
# Mô hình SVM với dữ liệu gốc - Tỉ lệ = 7:3 --- Kernel = linear ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.88      0.93      1158
#          2.0       0.57      0.88      0.69       207
#          3.0       0.76      0.92      0.83       123
#
#     accuracy                           0.88      1488
#    macro avg       0.78      0.89      0.82      1488
# weighted avg       0.92      0.88      0.89      1488
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.88      0.93       497
#          2.0       0.54      0.88      0.67        88
#          3.0       0.83      0.83      0.83        53
#
#     accuracy                           0.87       638
#    macro avg       0.79      0.86      0.81       638
# weighted avg       0.91      0.87      0.89       638
#
#
# Mô hình SVM với dữ liệu gốc - Tỉ lệ = 6:4 --- Kernel = linear ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.89      0.94       992
#          2.0       0.59      0.87      0.70       177
#          3.0       0.77      0.93      0.84       106
#
#     accuracy                           0.89      1275
#    macro avg       0.78      0.90      0.83      1275
# weighted avg       0.92      0.89      0.90      1275
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.89      0.93       663
#          2.0       0.55      0.85      0.66       118
#          3.0       0.79      0.81      0.80        70
#
#     accuracy                           0.88       851
#    macro avg       0.77      0.85      0.80       851
# weighted avg       0.91      0.88      0.89       851
#
#
# Mô hình SVM với dữ liệu gốc - Tỉ lệ = 8:1 --- Kernel = sigmoid ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.94      0.65      0.77      1323
#          2.0       0.50      0.67      0.57       236
#          3.0       0.21      0.68      0.32       141
#
#     accuracy                           0.66      1700
#    macro avg       0.55      0.67      0.55      1700
# weighted avg       0.82      0.66      0.71      1700
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.94      0.64      0.76       332
#          2.0       0.45      0.73      0.56        59
#          3.0       0.14      0.43      0.21        35
#
#     accuracy                           0.63       426
#    macro avg       0.51      0.60      0.51       426
# weighted avg       0.81      0.63      0.69       426
#
#
# Mô hình SVM với dữ liệu gốc - Tỉ lệ = 7:3 --- Kernel = sigmoid ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.95      0.65      0.78      1158
#          2.0       0.50      0.69      0.58       207
#          3.0       0.20      0.67      0.31       123
#
#     accuracy                           0.66      1488
#    macro avg       0.55      0.67      0.56      1488
# weighted avg       0.83      0.66      0.71      1488
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.94      0.65      0.77       497
#          2.0       0.49      0.75      0.59        88
#          3.0       0.16      0.49      0.24        53
#
#     accuracy                           0.65       638
#    macro avg       0.53      0.63      0.54       638
# weighted avg       0.81      0.65      0.70       638
#
#
# Mô hình SVM với dữ liệu gốc - Tỉ lệ = 6:4 --- Kernel = sigmoid ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.95      0.66      0.78       992
#          2.0       0.50      0.70      0.58       177
#          3.0       0.21      0.68      0.32       106
#
#     accuracy                           0.66      1275
#    macro avg       0.55      0.68      0.56      1275
# weighted avg       0.83      0.66      0.71      1275
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.93      0.66      0.77       663
#          2.0       0.49      0.69      0.58       118
#          3.0       0.17      0.53      0.26        70
#
#     accuracy                           0.65       851
#    macro avg       0.53      0.63      0.54       851
# weighted avg       0.81      0.65      0.70       851
#
#
# Mô hình SVM với dữ liệu gốc - Tỉ lệ = 8:1 --- Kernel = poly ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.93      0.96      1323
#          2.0       0.69      0.94      0.80       236
#          3.0       0.95      0.96      0.96       141
#
#     accuracy                           0.93      1700
#    macro avg       0.88      0.94      0.90      1700
# weighted avg       0.95      0.93      0.94      1700
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.97      0.92      0.94       332
#          2.0       0.62      0.83      0.71        59
#          3.0       0.83      0.83      0.83        35
#
#     accuracy                           0.90       426
#    macro avg       0.81      0.86      0.83       426
# weighted avg       0.91      0.90      0.90       426
#
#
# Mô hình SVM với dữ liệu gốc - Tỉ lệ = 7:3 --- Kernel = poly ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.93      0.96      1158
#          2.0       0.70      0.94      0.80       207
#          3.0       0.95      0.95      0.95       123
#
#     accuracy                           0.93      1488
#    macro avg       0.88      0.94      0.90      1488
# weighted avg       0.95      0.93      0.94      1488
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.98      0.92      0.94       497
#          2.0       0.61      0.88      0.72        88
#          3.0       0.89      0.75      0.82        53
#
#     accuracy                           0.90       638
#    macro avg       0.82      0.85      0.83       638
# weighted avg       0.92      0.90      0.90       638
#
#
# Mô hình SVM với dữ liệu gốc - Tỉ lệ = 6:4 --- Kernel = poly ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.94      0.96       992
#          2.0       0.72      0.93      0.81       177
#          3.0       0.95      0.94      0.95       106
#
#     accuracy                           0.94      1275
#    macro avg       0.89      0.94      0.91      1275
# weighted avg       0.95      0.94      0.94      1275
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.97      0.93      0.95       663
#          2.0       0.63      0.84      0.72       118
#          3.0       0.88      0.80      0.84        70
#
#     accuracy                           0.90       851
#    macro avg       0.83      0.86      0.84       851
# weighted avg       0.92      0.90      0.91       851
#
#
# Mô hình SVM với dữ liệu gốc - Tỉ lệ = 8:1 --- Kernel = rbf ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       1.00      0.90      0.94      1323
#          2.0       0.61      0.95      0.75       236
#          3.0       0.91      0.94      0.93       141
#
#     accuracy                           0.91      1700
#    macro avg       0.84      0.93      0.87      1700
# weighted avg       0.94      0.91      0.92      1700
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.88      0.93       332
#          2.0       0.55      0.88      0.68        59
#          3.0       0.78      0.80      0.79        35
#
#     accuracy                           0.87       426
#    macro avg       0.77      0.85      0.80       426
# weighted avg       0.91      0.87      0.88       426
#
#
# Mô hình SVM với dữ liệu gốc - Tỉ lệ = 7:3 --- Kernel = rbf ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       1.00      0.90      0.95      1158
#          2.0       0.62      0.96      0.75       207
#          3.0       0.93      0.93      0.93       123
#
#     accuracy                           0.91      1488
#    macro avg       0.85      0.93      0.88      1488
# weighted avg       0.94      0.91      0.92      1488
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.88      0.93       497
#          2.0       0.54      0.90      0.68        88
#          3.0       0.84      0.79      0.82        53
#
#     accuracy                           0.88       638
#    macro avg       0.79      0.86      0.81       638
# weighted avg       0.92      0.88      0.89       638
#
#
# Mô hình SVM với dữ liệu gốc - Tỉ lệ = 6:4 --- Kernel = rbf ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       1.00      0.90      0.95       992
#          2.0       0.62      0.97      0.76       177
#          3.0       0.93      0.93      0.93       106
#
#     accuracy                           0.91      1275
#    macro avg       0.85      0.93      0.88      1275
# weighted avg       0.94      0.91      0.92      1275
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.98      0.89      0.93       663
#          2.0       0.56      0.88      0.68       118
#          3.0       0.87      0.83      0.85        70
#
#     accuracy                           0.88       851
#    macro avg       0.80      0.87      0.82       851
# weighted avg       0.92      0.88      0.89       851

# %% [markdown]
# Dữ liệu giảm chiều bằng PCA

# %%
file_paths_pca = {
    "80_20": {
        'train': r'..\..\data\dimension_reduction\pca\train_80.csv',
        'test': r'..\..\data\dimension_reduction\pca\test_20.csv'
    },
    "70_30": {
        'train': r'..\..\data\dimension_reduction\pca\train_70.csv',
        'test': r'..\..\data\dimension_reduction\pca\test_30.csv'
    },
    "60_40": {
        'train': r'..\..\data\dimension_reduction\pca\train_60.csv',
        'test': r'..\..\data\dimension_reduction\pca\test_40.csv'
    }
}
for kernel in kernels:
    for split, paths in file_paths_pca.items():
        process_presplit_data(
            train_path=paths['train'],
            test_path=paths['test'],
            kernel = kernel,
            target_col='Target',
            method=f'PCA'
        )
# Out:
# Mô hình SVM với dữ liệu giảm chiều bằng PCA tỉ lệ 80_20 --- Kernel = linear ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.87      0.92      1323
#          2.0       0.55      0.90      0.68       236
#          3.0       0.75      0.82      0.79       141
#
#     accuracy                           0.87      1700
#    macro avg       0.76      0.86      0.80      1700
# weighted avg       0.91      0.87      0.88      1700
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.98      0.84      0.91       332
#          2.0       0.48      0.85      0.61        59
#          3.0       0.76      0.80      0.78        35
#
#     accuracy                           0.84       426
#    macro avg       0.74      0.83      0.76       426
# weighted avg       0.89      0.84      0.85       426
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng PCA tỉ lệ 70_30 --- Kernel = linear ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.86      0.92      1158
#          2.0       0.55      0.89      0.68       207
#          3.0       0.73      0.84      0.78       123
#
#     accuracy                           0.87      1488
#    macro avg       0.76      0.86      0.79      1488
# weighted avg       0.91      0.87      0.88      1488
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.84      0.91       497
#          2.0       0.48      0.89      0.63        88
#          3.0       0.77      0.77      0.77        53
#
#     accuracy                           0.84       638
#    macro avg       0.75      0.83      0.77       638
# weighted avg       0.90      0.84      0.86       638
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng PCA tỉ lệ 60_40 --- Kernel = linear ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.86      0.92       992
#          2.0       0.54      0.88      0.67       177
#          3.0       0.72      0.82      0.77       106
#
#     accuracy                           0.86      1275
#    macro avg       0.75      0.86      0.79      1275
# weighted avg       0.90      0.86      0.87      1275
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.85      0.91       663
#          2.0       0.50      0.87      0.63       118
#          3.0       0.76      0.79      0.77        70
#
#     accuracy                           0.85       851
#    macro avg       0.75      0.84      0.77       851
# weighted avg       0.90      0.85      0.86       851
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng PCA tỉ lệ 80_20 --- Kernel = sigmoid ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.93      0.64      0.76      1323
#          2.0       0.48      0.64      0.55       236
#          3.0       0.19      0.63      0.29       141
#
#     accuracy                           0.64      1700
#    macro avg       0.53      0.64      0.53      1700
# weighted avg       0.81      0.64      0.69      1700
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.94      0.61      0.74       332
#          2.0       0.44      0.69      0.54        59
#          3.0       0.13      0.43      0.20        35
#
#     accuracy                           0.61       426
#    macro avg       0.50      0.58      0.49       426
# weighted avg       0.80      0.61      0.67       426
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng PCA tỉ lệ 70_30 --- Kernel = sigmoid ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.94      0.64      0.76      1158
#          2.0       0.49      0.65      0.56       207
#          3.0       0.19      0.64      0.29       123
#
#     accuracy                           0.64      1488
#    macro avg       0.54      0.64      0.54      1488
# weighted avg       0.81      0.64      0.69      1488
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.93      0.63      0.75       497
#          2.0       0.49      0.72      0.58        88
#          3.0       0.15      0.49      0.23        53
#
#     accuracy                           0.63       638
#    macro avg       0.52      0.61      0.52       638
# weighted avg       0.81      0.63      0.69       638
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng PCA tỉ lệ 60_40 --- Kernel = sigmoid ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.94      0.65      0.77       992
#          2.0       0.49      0.68      0.57       177
#          3.0       0.19      0.62      0.29       106
#
#     accuracy                           0.65      1275
#    macro avg       0.54      0.65      0.54      1275
# weighted avg       0.81      0.65      0.70      1275
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.92      0.64      0.76       663
#          2.0       0.47      0.70      0.57       118
#          3.0       0.16      0.49      0.24        70
#
#     accuracy                           0.64       851
#    macro avg       0.52      0.61      0.52       851
# weighted avg       0.80      0.64      0.69       851
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng PCA tỉ lệ 80_20 --- Kernel = poly ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.92      0.95      1323
#          2.0       0.67      0.90      0.77       236
#          3.0       0.92      0.95      0.93       141
#
#     accuracy                           0.92      1700
#    macro avg       0.86      0.92      0.88      1700
# weighted avg       0.94      0.92      0.93      1700
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.96      0.91      0.93       332
#          2.0       0.57      0.78      0.66        59
#          3.0       0.79      0.77      0.78        35
#
#     accuracy                           0.88       426
#    macro avg       0.78      0.82      0.79       426
# weighted avg       0.90      0.88      0.88       426
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng PCA tỉ lệ 70_30 --- Kernel = poly ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.93      0.96      1158
#          2.0       0.67      0.90      0.77       207
#          3.0       0.94      0.93      0.94       123
#
#     accuracy                           0.92      1488
#    macro avg       0.87      0.92      0.89      1488
# weighted avg       0.94      0.92      0.93      1488
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.97      0.91      0.94       497
#          2.0       0.57      0.81      0.67        88
#          3.0       0.87      0.74      0.80        53
#
#     accuracy                           0.88       638
#    macro avg       0.80      0.82      0.80       638
# weighted avg       0.90      0.88      0.89       638
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng PCA tỉ lệ 60_40 --- Kernel = poly ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.94      0.96       992
#          2.0       0.71      0.91      0.80       177
#          3.0       0.96      0.93      0.95       106
#
#     accuracy                           0.93      1275
#    macro avg       0.89      0.93      0.90      1275
# weighted avg       0.94      0.93      0.94      1275
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.96      0.92      0.94       663
#          2.0       0.58      0.75      0.66       118
#          3.0       0.86      0.77      0.81        70
#
#     accuracy                           0.88       851
#    macro avg       0.80      0.82      0.80       851
# weighted avg       0.90      0.88      0.89       851
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng PCA tỉ lệ 80_20 --- Kernel = rbf ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       1.00      0.89      0.94      1323
#          2.0       0.61      0.96      0.74       236
#          3.0       0.91      0.94      0.92       141
#
#     accuracy                           0.90      1700
#    macro avg       0.84      0.93      0.87      1700
# weighted avg       0.94      0.90      0.91      1700
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.87      0.93       332
#          2.0       0.54      0.88      0.67        59
#          3.0       0.75      0.77      0.76        35
#
#     accuracy                           0.87       426
#    macro avg       0.76      0.84      0.79       426
# weighted avg       0.91      0.87      0.88       426
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng PCA tỉ lệ 70_30 --- Kernel = rbf ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       1.00      0.89      0.94      1158
#          2.0       0.61      0.96      0.75       207
#          3.0       0.91      0.93      0.92       123
#
#     accuracy                           0.91      1488
#    macro avg       0.84      0.93      0.87      1488
# weighted avg       0.94      0.91      0.91      1488
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.87      0.93       497
#          2.0       0.52      0.88      0.66        88
#          3.0       0.79      0.77      0.78        53
#
#     accuracy                           0.86       638
#    macro avg       0.77      0.84      0.79       638
# weighted avg       0.91      0.86      0.88       638
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng PCA tỉ lệ 60_40 --- Kernel = rbf ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       1.00      0.89      0.94       992
#          2.0       0.61      0.95      0.74       177
#          3.0       0.85      0.94      0.90       106
#
#     accuracy                           0.90      1275
#    macro avg       0.82      0.93      0.86      1275
# weighted avg       0.93      0.90      0.91      1275
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.98      0.87      0.92       663
#          2.0       0.54      0.89      0.67       118
#          3.0       0.76      0.80      0.78        70
#
#     accuracy                           0.86       851
#    macro avg       0.76      0.85      0.79       851
# weighted avg       0.90      0.86      0.88       851

# %% [markdown]
# Dữ liệu giảm chiều bằng LDA

# %%
file_paths_lda = {
    "80_20": {
        'train': r'..\..\data\dimension_reduction\lda\train_80.csv',
        'test': r'..\..\data\dimension_reduction\lda\test_20.csv'
    },
    "70_30": {
        'train': r'..\..\data\dimension_reduction\lda\train_70.csv',
        'test': r'..\..\data\dimension_reduction\lda\test_30.csv'
    },
    "60_40": {
        'train': r'..\..\data\dimension_reduction\lda\train_60.csv',
        'test': r'..\..\data\dimension_reduction\lda\test_40.csv'
    }
}
for kernel in kernels:
    for split, paths in file_paths_lda.items():
        process_presplit_data(
            train_path=paths['train'],
            test_path=paths['test'],
            kernel = kernel,
            target_col='Target',
            method=f'LDA'
        )
# Out:
# Mô hình SVM với dữ liệu giảm chiều bằng LDA tỉ lệ 80_20 --- Kernel = linear ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.98      0.84      0.91      1323
#          2.0       0.51      0.85      0.64       236
#          3.0       0.69      0.83      0.75       141
#
#     accuracy                           0.84      1700
#    macro avg       0.73      0.84      0.77      1700
# weighted avg       0.89      0.84      0.86      1700
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.98      0.85      0.91       332
#          2.0       0.51      0.83      0.63        59
#          3.0       0.65      0.74      0.69        35
#
#     accuracy                           0.84       426
#    macro avg       0.71      0.81      0.75       426
# weighted avg       0.88      0.84      0.85       426
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng LDA tỉ lệ 70_30 --- Kernel = linear ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.98      0.85      0.91      1158
#          2.0       0.53      0.86      0.66       207
#          3.0       0.69      0.85      0.76       123
#
#     accuracy                           0.85      1488
#    macro avg       0.74      0.85      0.78      1488
# weighted avg       0.90      0.85      0.86      1488
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.97      0.86      0.91       497
#          2.0       0.49      0.83      0.61        88
#          3.0       0.76      0.74      0.75        53
#
#     accuracy                           0.84       638
#    macro avg       0.74      0.81      0.76       638
# weighted avg       0.89      0.84      0.86       638
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng LDA tỉ lệ 60_40 --- Kernel = linear ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.84      0.91       992
#          2.0       0.52      0.86      0.65       177
#          3.0       0.65      0.86      0.74       106
#
#     accuracy                           0.84      1275
#    macro avg       0.72      0.85      0.77      1275
# weighted avg       0.89      0.84      0.86      1275
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.84      0.91       663
#          2.0       0.50      0.86      0.63       118
#          3.0       0.72      0.81      0.77        70
#
#     accuracy                           0.84       851
#    macro avg       0.73      0.84      0.77       851
# weighted avg       0.90      0.84      0.86       851
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng LDA tỉ lệ 80_20 --- Kernel = sigmoid ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.94      0.79      0.85      1323
#          2.0       0.41      0.48      0.44       236
#          3.0       0.29      0.63      0.40       141
#
#     accuracy                           0.73      1700
#    macro avg       0.54      0.63      0.56      1700
# weighted avg       0.81      0.73      0.76      1700
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.93      0.79      0.85       332
#          2.0       0.45      0.54      0.49        59
#          3.0       0.26      0.54      0.35        35
#
#     accuracy                           0.73       426
#    macro avg       0.55      0.62      0.56       426
# weighted avg       0.81      0.73      0.76       426
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng LDA tỉ lệ 70_30 --- Kernel = sigmoid ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.92      0.84      0.88      1158
#          2.0       0.47      0.56      0.51       207
#          3.0       0.39      0.60      0.47       123
#
#     accuracy                           0.78      1488
#    macro avg       0.59      0.67      0.62      1488
# weighted avg       0.82      0.78      0.79      1488
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.92      0.82      0.87       497
#          2.0       0.48      0.64      0.55        88
#          3.0       0.35      0.51      0.41        53
#
#     accuracy                           0.77       638
#    macro avg       0.58      0.66      0.61       638
# weighted avg       0.81      0.77      0.79       638
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng LDA tỉ lệ 60_40 --- Kernel = sigmoid ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.93      0.78      0.85       992
#          2.0       0.40      0.51      0.45       177
#          3.0       0.27      0.58      0.37       106
#
#     accuracy                           0.72      1275
#    macro avg       0.54      0.62      0.56      1275
# weighted avg       0.81      0.72      0.75      1275
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.94      0.78      0.85       663
#          2.0       0.44      0.56      0.49       118
#          3.0       0.24      0.51      0.33        70
#
#     accuracy                           0.73       851
#    macro avg       0.54      0.62      0.56       851
# weighted avg       0.81      0.73      0.76       851
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng LDA tỉ lệ 80_20 --- Kernel = poly ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.96      0.92      0.94      1323
#          2.0       0.61      0.81      0.69       236
#          3.0       0.87      0.78      0.82       141
#
#     accuracy                           0.89      1700
#    macro avg       0.81      0.83      0.82      1700
# weighted avg       0.91      0.89      0.90      1700
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.96      0.93      0.94       332
#          2.0       0.60      0.76      0.67        59
#          3.0       0.77      0.69      0.73        35
#
#     accuracy                           0.88       426
#    macro avg       0.78      0.79      0.78       426
# weighted avg       0.90      0.88      0.89       426
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng LDA tỉ lệ 70_30 --- Kernel = poly ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.96      0.92      0.94      1158
#          2.0       0.61      0.81      0.70       207
#          3.0       0.85      0.80      0.82       123
#
#     accuracy                           0.89      1488
#    macro avg       0.81      0.84      0.82      1488
# weighted avg       0.91      0.89      0.90      1488
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.96      0.92      0.94       497
#          2.0       0.59      0.81      0.68        88
#          3.0       0.84      0.68      0.75        53
#
#     accuracy                           0.88       638
#    macro avg       0.80      0.80      0.79       638
# weighted avg       0.90      0.88      0.89       638
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng LDA tỉ lệ 60_40 --- Kernel = poly ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.96      0.92      0.94       992
#          2.0       0.62      0.79      0.69       177
#          3.0       0.83      0.79      0.81       106
#
#     accuracy                           0.89      1275
#    macro avg       0.81      0.83      0.82      1275
# weighted avg       0.90      0.89      0.90      1275
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.97      0.92      0.95       663
#          2.0       0.61      0.82      0.70       118
#          3.0       0.82      0.73      0.77        70
#
#     accuracy                           0.89       851
#    macro avg       0.80      0.82      0.81       851
# weighted avg       0.91      0.89      0.90       851
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng LDA tỉ lệ 80_20 --- Kernel = rbf ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.83      0.90      1323
#          2.0       0.51      0.92      0.66       236
#          3.0       0.70      0.84      0.76       141
#
#     accuracy                           0.84      1700
#    macro avg       0.73      0.86      0.77      1700
# weighted avg       0.90      0.84      0.86      1700
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.83      0.90       332
#          2.0       0.49      0.83      0.61        59
#          3.0       0.61      0.77      0.68        35
#
#     accuracy                           0.83       426
#    macro avg       0.69      0.81      0.73       426
# weighted avg       0.89      0.83      0.85       426
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng LDA tỉ lệ 70_30 --- Kernel = rbf ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.84      0.91      1158
#          2.0       0.53      0.91      0.67       207
#          3.0       0.70      0.85      0.77       123
#
#     accuracy                           0.85      1488
#    macro avg       0.74      0.87      0.78      1488
# weighted avg       0.90      0.85      0.86      1488
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.98      0.84      0.91       497
#          2.0       0.48      0.85      0.62        88
#          3.0       0.67      0.74      0.70        53
#
#     accuracy                           0.83       638
#    macro avg       0.71      0.81      0.74       638
# weighted avg       0.89      0.83      0.85       638
#
#
# Mô hình SVM với dữ liệu giảm chiều bằng LDA tỉ lệ 60_40 --- Kernel = rbf ---
# [Train] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.83      0.90       992
#          2.0       0.52      0.92      0.66       177
#          3.0       0.68      0.84      0.75       106
#
#     accuracy                           0.84      1275
#    macro avg       0.73      0.86      0.77      1275
# weighted avg       0.90      0.84      0.86      1275
#
# [Test] Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.84      0.91       663
#          2.0       0.51      0.92      0.65       118
#          3.0       0.68      0.76      0.72        70
#
#     accuracy                           0.84       851
#    macro avg       0.73      0.84      0.76       851
# weighted avg       0.90      0.84      0.86       851
